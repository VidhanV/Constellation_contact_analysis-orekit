# %%
import orekit
orekit.initVM()

# %%
from orekit.pyhelpers import download_orekit_data_curdir, setup_orekit_curdir
download_orekit_data_curdir()
setup_orekit_curdir()
# Out:
# Downloading file from: https://gitlab.orekit.org/orekit/orekit-data/-/archive/main/orekit-data-main.zip

# %%
import math
from collections import defaultdict

from java.util import ArrayList
from java.net import URL  # Add this line
from java.io import BufferedReader, InputStreamReader
from java.lang import StringBuilder

from org.hipparchus.geometry.euclidean.threed import Vector3D

from org.orekit.orbits import (
    KeplerianOrbit,
    PositionAngleType,
    WalkerConstellation,
    WalkerConstellationSlot,
    OrbitType
)
from org.orekit.frames import FramesFactory
from org.orekit.time import AbsoluteDate, TimeScalesFactory
from org.orekit.utils import Constants, IERSConventions
from org.orekit.bodies import OneAxisEllipsoid
from org.orekit.geometry.fov import CircularFieldOfView
from org.orekit.propagation.analytical import KeplerianPropagator
from org.orekit.propagation.analytical.tle import TLE, TLEPropagator  # Add this if using TLE
from org.orekit.propagation.events import (
    InterSatDirectViewDetector,
    FieldOfViewDetector,
    RelativeDistanceDetector,
    BooleanDetector,
    EventsLogger,
    VisibilityTrigger
)
from org.orekit.propagation.events.handlers import ContinueOnEvent

# %%
import urllib.request
import ssl
from org.orekit.propagation.analytical.tle import TLE
from org.orekit.utils import Constants

mu = Constants.WGS84_EARTH_MU

# Function to fetch Globalstar TLEs and store with IDs
def fetch_globalstar_tles_with_ids():
    context = ssl._create_unverified_context()
    url = "https://celestrak.org/NORAD/elements/gp.php?GROUP=globalstar&FORMAT=tle"
    
    tle_data = []  # List of tuples (tle_object, globalstar_id)

    try:
        print("Fetching TLEs from CelesTrak...")
        request = urllib.request.Request(url)
        request.add_header("User-Agent", "Mozilla/5.0")

        with urllib.request.urlopen(request, context=context, timeout=30) as response:
            data = response.read().decode("utf-8")
            lines = data.splitlines()

            i = 0
            while i < len(lines):
                name = lines[i].strip()

                # TLE format: name line + line1 + line2
                if i + 2 < len(lines):
                    line1 = lines[i + 1].strip()
                    line2 = lines[i + 2].strip()

                    if line1.startswith("1 ") and line2.startswith("2 "):
                        try:
                            tle = TLE(line1, line2)
                            tle_data.append((tle, name))
                        except Exception as e:
                            print(f"✗ TLE creation failed for {name}: {e}")

                    i += 3
                else:
                    break

    except Exception as e:
        print(f"Error fetching Globalstar TLEs: {e}")

    return tle_data


# Fetch TLEs with Globalstar IDs
print("\nFetching real Globalstar TLEs...")
tle_data = fetch_globalstar_tles_with_ids()

# Separate into lists for convenience
tle_list = [item[0] for item in tle_data]
globalstar_ids = [item[1] for item in tle_data]

print(f"\n=== RESULTS ===")
print(f"Found {len(tle_list)} Globalstar satellites")

# Print all TLEs with Globalstar IDs
print("\n" + "=" * 80)
print("GLOBALSTAR CONSTELLATION - RAW TLE DATA WITH IDS")
print("=" * 80)

for i, (tle, globalstar_id) in enumerate(tle_data):
    print(f"\n{globalstar_id}")
    print(tle.getLine1())
    print(tle.getLine2())

print("\n" + "=" * 80)
print(f"Total: {len(tle_data)} satellites displayed")
print("=" * 80)

# Also print a simple list of all Globalstar IDs found
print("\nGlobalstar Satellite IDs:")
globalstar_numbers = [id_str.replace("GLOBALSTAR ", "") for id_str in globalstar_ids]
print(", ".join(globalstar_numbers))
# Out:
# Fetching real Globalstar TLEs...
# Fetching TLEs from CelesTrak...
#
# === RESULTS ===
# Found 85 Globalstar satellites
#
# ================================================================================
# GLOBALSTAR CONSTELLATION - RAW TLE DATA WITH IDS
# ================================================================================
#
# GLOBALSTAR M001
# 1 25162U 98008A   26071.76403523 -.00000049  00000+0  36259-3 0  9998
# 2 25162  52.0021 271.4986 0002350  98.5530 343.4269 12.38229762276980
#
# GLOBALSTAR M004
# 1 25163U 98008B   26071.65195027 -.00000071  00000+0  18117-3 0  9992
# 2 25163  52.0022 315.1201 0003316 152.3522 225.9733 12.63416584295621
#
# GLOBALSTAR M002
# 1 25164U 98008C   26071.92178156 -.00000076  00000+0  17642-4 0  9995
# 2 25164  52.0015 286.3963 0000498 290.5830  69.4936 11.61515227215295
#
# GLOBALSTAR M003
# 1 25165U 98008D   26071.65535671 -.00000196  00000+0 -11353-2 0  9990
# 2 25165  51.9845 144.9188 0008698 112.1655  54.1154 12.12023749265778
#
# GLOBALSTAR M014
# 1 25306U 98023A   26071.75753677 -.00000069  00000+0  16227-3 0  9997
# 2 25306  51.9826 204.3796 0001790 125.5512  26.5938 11.65485050222484
#
# GLOBALSTAR M006
# 1 25307U 98023B   26071.99526337 -.00000044  00000+0  65215-3 0  9999
# 2 25307  51.9923 266.3033 0002386 223.6514 304.6140 11.58177954247978
#
# GLOBALSTAR M015
# 1 25308U 98023C   26071.79845112 -.00000047  00000+0  60043-3 0  9990
# 2 25308  51.9859  17.5730 0012488 193.3048 183.1616 11.48861038224959
#
# GLOBALSTAR M008
# 1 25309U 98023D   26071.55481897 -.00000108  00000+0 -91272-4 0  9999
# 2 25309  51.9959 139.9786 0002557  31.4458 107.8077 12.36081419271034
#
# GLOBALSTAR M023
# 1 25621U 99004A   26071.65021102 -.00000059  00000+0  24685-3 0  9993
# 2 25621  52.0123 315.9574 0009943   4.2997  13.1550 12.62518749249646
#
# GLOBALSTAR M040
# 1 25622U 99004B   26071.73320848 -.00000080  00000+0  13458-3 0  9992
# 2 25622  51.9935 320.2541 0000109 292.7761 102.3384 12.62029595249166
#
# GLOBALSTAR M036
# 1 25623U 99004C   26071.93343545 -.00000037  00000+0  66947-3 0  9997
# 2 25623  51.9949 251.9487 0010224 202.5950 265.7600 11.86620888210888
#
# GLOBALSTAR M038
# 1 25624U 99004D   26072.01216284 -.00000077  00000+0  14967-3 0  9996
# 2 25624  52.0007  17.3738 0001311 257.1678 181.9438 12.32542128235527
#
# GLOBALSTAR M022
# 1 25649U 99012A   26071.99342740 -.00000022  00000+0  78465-3 0  9998
# 2 25649  52.0032 280.1582 0002553   1.3145 147.0645 12.02510998208717
#
# GLOBALSTAR M041
# 1 25650U 99012B   26071.58902804 -.00000113  00000+0 -35084-3 0  9990
# 2 25650  52.0014 170.8889 0002003 129.2451 230.8563 11.96683982210410
#
# GLOBALSTAR M046
#
# GLOBALSTAR M094
# 1 39074U 13005C   26071.92746595 -.00000093  00000+0  60568-4 0  9996
# 2 39074  51.9950  83.8807 0000549 118.6294 241.4628 12.62267307606316
#
# GLOBALSTAR M096
# 1 39075U 13005D   26071.62390370 -.00000100  00000+0  18316-4 0  9993
# 2 39075  52.0064 133.5313 0000694 116.0755 244.0183 12.62263713605192
#
# GLOBALSTAR M078
# 1 39076U 13005E   26071.83476637 -.00000091  00000+0  74048-4 0  9991
# 2 39076  51.9862 217.0302 0001487  77.1024 283.0009 12.62276077603847
#
# GLOBALSTAR M095
# 1 39077U 13005F   26071.78220402 -.00000112  00000+0 -47927-4 0  9994
# 2 39077  52.0074 214.6588 0001267 100.7995 259.3015 12.62276202603696
#
# GLOBALSTAR M087
# 1 52888U 22064A   26071.24131944 -.00000088  00000+0  89269-4 0  9993
# 2 52888  52.0028 357.6009 0000770  87.1303 272.9652 12.62267010178899
#
# ================================================================================
# Total: 85 satellites displayed
# ================================================================================
#
# Globalstar Satellite IDs:
# M001, M004, M002, M003, M014, M006, M015, M008, M023, M040, M036, M038, M022, M041, M046, M037, M045, M019, M044, M042, M025, M049, M047, M052, M035, M032, M051, M030, M048, M026, M043, M028, M024, M027, M054, M053, M058, M050, M033, M055, M057, M059, M056, M031, M039, M034, M029, M061, M063, M062, M060, M064, M065, M069, M072, M071, M067, M070, M066, M068, M079, M074, M076, M077, M075, M073, M083, M088, M091, M085, M081, M089, M084, M080, M082, M092, M090, M086, M097, M093, M094, M096, M078, M095, M087

# %%
# ============================================================
# 3) BUILD TLE PROPAGATORS FOR EACH IRIDIUM SATELLITE
# ============================================================
from org.orekit.propagation.analytical.tle import TLEPropagator

global_props = {}
global_id_map = {}  # Map propagator keys to Iridium IDs

for i, tle in enumerate(tle_list):
    propagator = TLEPropagator.selectExtrapolator(tle)
    global_props[i] = propagator  # Use simple integer index
    global_id_map[i] = globalstar_ids[i]  # Store the Iridium ID

print(f"\nBuilt {len(global_props)} Globalstar TLE propagators.")

# Optional: Print first few satellites to verify
print("\nFirst 5 satellites:")
for i in range(min(5, len(global_props))):
    print(f"  Sat {i}: {global_id_map[i]}")
# Out:
# Built 85 Globalstar TLE propagators.
#
# First 5 satellites:
#   Sat 0: GLOBALSTAR M001
#   Sat 1: GLOBALSTAR M004
#   Sat 2: GLOBALSTAR M002
#   Sat 3: GLOBALSTAR M003
#   Sat 4: GLOBALSTAR M014

# %%
from org.orekit.time import AbsoluteDate, TimeScalesFactory
from org.orekit.frames import FramesFactory
from org.orekit.utils import Constants, IERSConventions
from org.orekit.bodies import OneAxisEllipsoid, CelestialBodyFactory

UTC   = TimeScalesFactory.getUTC()
frame = FramesFactory.getEME2000()
mu    = Constants.WGS84_EARTH_MU

ITRF  = FramesFactory.getITRF(IERSConventions.IERS_2010, True)
earth = OneAxisEllipsoid(
    float(Constants.WGS84_EARTH_EQUATORIAL_RADIUS),
    float(Constants.WGS84_EARTH_FLATTENING),
    ITRF
)

sun  = CelestialBodyFactory.getSun()
moon = CelestialBodyFactory.getMoon()

# %%
# ============================================================
# 4) DUMMY SPACECRAFT ORBIT (REPLACE LATER WITH YOUR OWN)
# ============================================================
epoch= AbsoluteDate(2026, 3, 14, 18, 59, 0.0, UTC);
sc_sma  = float(Constants.WGS84_EARTH_EQUATORIAL_RADIUS + 500000.0)  # 500 km
sc_ecc  = 0.001
sc_inc  = math.radians(37.0)
sc_raan = math.radians(20.0)
sc_aop  = 0.0
sc_ta   = math.radians(0.0)

sc_orbit = KeplerianOrbit(
    float(sc_sma),
    float(sc_ecc),
    float(sc_inc),
    float(sc_aop),
    float(sc_raan),
    float(sc_ta),
    PositionAngleType.TRUE,
    frame,
    epoch,
    float(mu)
)# ============================================================
# 4) SPACECRAFT ORBIT WITH NUMERICAL PROPAGATOR
#    Forces: J2 + Drag + Sun/Moon 3rd body
# ============================================================

from org.hipparchus.ode.nonstiff import DormandPrince853Integrator
from org.orekit.propagation import SpacecraftState
from org.orekit.propagation.numerical import NumericalPropagator
from org.orekit.orbits import OrbitType
from orekit import JArray_double
from org.orekit.forces.gravity import HolmesFeatherstoneAttractionModel, ThirdBodyAttraction
from org.orekit.forces.gravity.potential import GravityFieldFactory
from org.orekit.bodies import CelestialBodyFactory
from org.orekit.models.earth.atmosphere import HarrisPriester
from org.orekit.forces.drag import DragForce, IsotropicDrag
from org.orekit.frames import FramesFactory

# ------------------------------------------------------------
# Dummy spacecraft initial orbit (replace later with yours)
# ------------------------------------------------------------
sc_sma  = float(Constants.WGS84_EARTH_EQUATORIAL_RADIUS + 500000.0)  # 500 km
sc_ecc  = 0.001
sc_inc  = math.radians(37.0)
sc_raan = math.radians(20.0)
sc_aop  = 0.0
sc_ta   = math.radians(0.0)

sc_orbit = KeplerianOrbit(
    float(sc_sma),
    float(sc_ecc),
    float(sc_inc),
    float(sc_aop),
    float(sc_raan),
    float(sc_ta),
    PositionAngleType.TRUE,
    frame,
    epoch,
    float(mu)
)


# ------------------------------------------------------------
# Spacecraft physical properties for drag
# ------------------------------------------------------------
sc_mass = 50.0      # kg
Cd      = 2.2
area    = 15      # m^2

initial_state = SpacecraftState(sc_orbit, float(sc_mass))
sc_initial_state = initial_state
print("\nDummy spacecraft orbit created:")
print(f"  Altitude : {(sc_sma - Constants.WGS84_EARTH_EQUATORIAL_RADIUS)/1000:.1f} km")
print(f"  Period   : {sc_orbit.getKeplerianPeriod()/60:.2f} min")
print(f"  Inc      : {math.degrees(sc_inc):.1f} deg")

# ------------------------------------------------------------
# Earth model for gravity/drag occultation frame use
# ------------------------------------------------------------
ITRF = FramesFactory.getITRF(IERSConventions.IERS_2010, True)

earth = OneAxisEllipsoid(
    float(Constants.WGS84_EARTH_EQUATORIAL_RADIUS),
    float(Constants.WGS84_EARTH_FLATTENING),
    ITRF
)

# ------------------------------------------------------------
# Numerical integrator
# ------------------------------------------------------------
# dP is a position error scale used to build tolerances
dP = 10.0  # meters
orbit_type = OrbitType.CARTESIAN
tol = NumericalPropagator.tolerances(float(dP), sc_orbit, orbit_type)

min_step = 0.001
max_step = 300.0
integrator = DormandPrince853Integrator(
    float(min_step),
    float(max_step),
    JArray_double.cast_(tol[0]),
    JArray_double.cast_(tol[1])
)

# ------------------------------------------------------------
# Numerical propagator
# ------------------------------------------------------------
sc_prop = NumericalPropagator(integrator)
sc_prop.setOrbitType(orbit_type)
sc_prop.setInitialState(initial_state)
sc_prop.setMu(float(mu))

# ------------------------------------------------------------
# Force model 1: Earth gravity with J2 only
# ------------------------------------------------------------
# degree=2, order=0 => zonal J2-only gravity field
gravity_provider = GravityFieldFactory.getNormalizedProvider(2, 0)
j2_model = HolmesFeatherstoneAttractionModel(
    earth.getBodyFrame(),
    gravity_provider
)
sc_prop.addForceModel(j2_model)

# ------------------------------------------------------------
# Force model 2: Third-body perturbations (Sun and Moon)
# ------------------------------------------------------------
sun  = CelestialBodyFactory.getSun()
moon = CelestialBodyFactory.getMoon()

sun_3body  = ThirdBodyAttraction(sun)
moon_3body = ThirdBodyAttraction(moon)

sc_prop.addForceModel(sun_3body)
sc_prop.addForceModel(moon_3body)

# ------------------------------------------------------------
# Force model 3: Atmospheric drag
# ------------------------------------------------------------
# Harris-Priester is a good first choice because it does not need
# external space-weather inputs.
atmosphere = HarrisPriester(sun, earth)

drag_spacecraft = IsotropicDrag(float(area), float(Cd))
drag_model = DragForce(atmosphere, drag_spacecraft)

sc_prop.addForceModel(drag_model)

print("\nNumerical spacecraft propagator configured with:")
print("  - Earth gravity: J2 only")
print("  - Third body: Sun")
print("  - Third body: Moon")
print("  - Drag: Harris-Priester + IsotropicDrag")
print(f"  - Mass = {sc_mass:.2f} kg, Cd = {Cd:.2f}, Area = {area:.3f} m^2")

# ============================================================
# 5) EARTH MODEL FOR OCCULTATION
# ============================================================
ITRF = FramesFactory.getITRF(IERSConventions.IERS_2010, True)

earth = OneAxisEllipsoid(
    float(Constants.WGS84_EARTH_EQUATORIAL_RADIUS),
    float(Constants.WGS84_EARTH_FLATTENING),
    ITRF
)

# ============================================================
# 6) ANTENNA FOV MODEL
# ============================================================
half_aperture_deg = 60.0
half_aperture_rad = math.radians(half_aperture_deg)

boresight = Vector3D.PLUS_K
fov_margin = 0.0

antenna_fov = CircularFieldOfView(
    boresight,
    float(half_aperture_rad),
    float(fov_margin)
)

# ============================================================
# 7) MAX RANGE
# ============================================================
max_range_m = 2_500_000.0   # 2500 km

# ============================================================
# 8) SET GLOBALSTAR SATELLITE ATTITUDE
#    Approximation: nadir-pointing antenna boresight
# ============================================================
from org.orekit.attitudes import NadirPointing

for sat_key, sat_prop in global_props.items():
    sat_prop.setAttitudeProvider(NadirPointing(frame, earth))

print(f"Set nadir-pointing attitude for {len(global_props)} Globalstar propagators.")

# ============================================================
# 9) BUILD SPACECRAFT EPHEMERIS ONCE
# ============================================================
start_date = epoch
end_date   = epoch.shiftedBy(24.0 * 3600.0)

ephem_gen = sc_prop.getEphemerisGenerator()

print("\nPropagating spacecraft once to build ephemeris...")
sc_final_state = sc_prop.propagate(start_date, end_date)
sc_ephem = ephem_gen.getGeneratedEphemeris()

sc_ephem_start = start_date
sc_ephem_end   = sc_final_state.getDate()

print("Spacecraft ephemeris generated")
print(f"  Start : {sc_ephem_start}")
print(f"  End   : {sc_ephem_end}")

# ============================================================
# 10) OPTIONAL DEBUG AT INITIAL EPOCH FOR ONE SATELLITE
# ============================================================
test_key = 0
sat_prop_test = global_props[test_key]

los_test = InterSatDirectViewDetector(earth, sc_ephem)

raw_fov_test = FieldOfViewDetector(
    sc_ephem,
    0.0,
    VisibilityTrigger.VISIBLE_ONLY_WHEN_FULLY_IN_FOV,
    antenna_fov
)
fov_inside_test = BooleanDetector.notCombine(raw_fov_test)

raw_range_test = RelativeDistanceDetector(sc_ephem, float(max_range_m))
range_within_test = BooleanDetector.notCombine(raw_range_test)

sat_initial_state_test = sat_prop_test.propagate(sc_ephem_start)

print(f"\nInitial detector debug for satellite {test_key} ({global_id_map[test_key]}):")
print("  LOS g           =", los_test.g(sat_initial_state_test))
print("  inside-FOV g    =", fov_inside_test.g(sat_initial_state_test))
print("  within-range g  =", range_within_test.g(sat_initial_state_test))

# ============================================================
# 11) CONTACT ANALYSIS: GLOBALSTAR SATELLITE AS OBSERVER
# ============================================================
contact_windows = []

print("\n================ CONTACT ANALYSIS ================\n")
print(f"FOV half-angle : {half_aperture_deg:.1f} deg")
print(f"Max range      : {max_range_m/1000.0:.1f} km")
print(f"Start          : {sc_ephem_start}")
print(f"End            : {sc_ephem_end}\n")

for sat_key, sat_prop in global_props.items():

    logger = EventsLogger()

    # --------------------------------------------------------
    # 1) Get satellite state at analysis start FIRST
    #    Do this before attaching any detector that uses sc_ephem
    # --------------------------------------------------------
    sat_initial_state = sat_prop.propagate(sc_ephem_start)

    # --------------------------------------------------------
    # 2) Build detectors using spacecraft ephemeris as target
    # --------------------------------------------------------
    los_detector = InterSatDirectViewDetector(earth, sc_ephem)

    raw_fov_detector = FieldOfViewDetector(
        sc_ephem,
        0.0,
        VisibilityTrigger.VISIBLE_ONLY_WHEN_FULLY_IN_FOV,
        antenna_fov
    )
    fov_inside_detector = BooleanDetector.notCombine(raw_fov_detector)

    raw_range_detector = RelativeDistanceDetector(sc_ephem, float(max_range_m))
    range_within_detector = BooleanDetector.notCombine(raw_range_detector)

    combined_detector = BooleanDetector.andCombine([
        los_detector,
        fov_inside_detector,
        range_within_detector
    ]).withHandler(ContinueOnEvent()) \
     .withMaxCheck(60.0) \
     .withThreshold(1.0e-6)
    
    
    g_los = los_detector.g(sat_initial_state)
    g_fov = fov_inside_detector.g(sat_initial_state)
    g_rng = range_within_detector.g(sat_initial_state)

    
    in_contact = (g_los > 0.0) and (g_fov > 0.0) and (g_rng > 0.0)
    current_start = sc_ephem_start if in_contact else None

    
    monitored_detector = logger.monitorDetector(combined_detector)
    sat_prop.addEventDetector(monitored_detector)

    # --------------------------------------------------------
    # 5) Propagate satellite only over valid spacecraft-ephem interval
    # --------------------------------------------------------
    _ = sat_prop.propagate(sc_ephem_start, sc_ephem_end)

    # --------------------------------------------------------
    # 6) Collect events for this satellite
    # --------------------------------------------------------
    sat_events = []
    for ev in logger.getLoggedEvents():
        sat_events.append({
            "date": ev.getState().getDate(),
            "increasing": ev.isIncreasing()
        })

    sat_events.sort(key=lambda e: e["date"].durationFrom(sc_ephem_start))

    # --------------------------------------------------------
    # 7) Convert events to contact windows
    # --------------------------------------------------------
    for ev in sat_events:
        ev_date = ev["date"]
        increasing = ev["increasing"]

        if increasing:
            if not in_contact:
                current_start = ev_date
                in_contact = True
        else:
            if in_contact and current_start is not None:
                duration_s = ev_date.durationFrom(current_start)
                if duration_s >= 0.0:
                    contact_windows.append({
                        "sat_index": sat_key,
                        "global_id": global_id_map[sat_key],
                        "start": current_start,
                        "end": ev_date,
                        "duration_s": duration_s
                    })
                current_start = None
                in_contact = False

    # --------------------------------------------------------
    # 8) Open window until analysis end
    # --------------------------------------------------------
    if in_contact and current_start is not None:
        duration_s = sc_ephem_end.durationFrom(current_start)
        if duration_s >= 0.0:
            contact_windows.append({
                "sat_index": sat_key,
                "global_id": global_id_map[sat_key],
                "start": current_start,
                "end": sc_ephem_end,
                "duration_s": duration_s
            })
# ============================================================
# 12) PRINT CONTACT WINDOWS
# ============================================================
print("\n================ CONTACT WINDOWS ================\n")
print(f"FOV half-angle : {half_aperture_deg:.1f} deg")
print(f"Max range      : {max_range_m/1000.0:.1f} km\n")

if len(contact_windows) == 0:
    print("No contact windows found in the analysis interval.")
else:
    print(f"{'Idx':>4} {'Globalstar ID':>15} {'Start UTC':>28} {'End UTC':>28} {'Dur (min)':>10}")
    print("-" * 95)

    for w in contact_windows:
        print(f"{w['sat_index']:>4} "
              f"{w['global_id']:>15} "
              f"{str(w['start']):>28} "
              f"{str(w['end']):>28} "
              f"{w['duration_s']/60.0:>10.2f}")

# ============================================================
# 13) SUMMARY PER SATELLITE
# ============================================================
summary = defaultdict(lambda: {"count": 0, "total_s": 0.0})

for w in contact_windows:
    key = w["sat_index"]
    summary[key]["count"] += 1
    summary[key]["total_s"] += w["duration_s"]

print("\n================ CONTACT SUMMARY ================\n")
print(f"{'Idx':>4} {'Globalstar ID':>15} {'#Windows':>9} {'Total (min)':>12} {'Total (hr)':>11}")
print("-" * 60)

for key in sorted(summary.keys()):
    count = summary[key]["count"]
    total_min = summary[key]["total_s"] / 60.0
    total_hr  = summary[key]["total_s"] / 3600.0
    print(f"{key:>4} "
          f"{global_id_map[key]:>15} "
          f"{count:>9} "
          f"{total_min:>12.2f} "
          f"{total_hr:>11.2f}")

print(f"\nTotal contact windows found: {len(contact_windows)}")

# ============================================================
# 14) DEBUG RANGE AT CONTACT START (SAME FRAME)
# ============================================================
if len(contact_windows) > 0:
    print("\n========== DEBUG RANGE AT CONTACT START ==========\n")

    for w in contact_windows:
        key = w["sat_index"]
        t0  = w["start"]

        sat_prop = global_props[key]

        sat_state = sat_prop.propagate(t0)
        sc_state  = sc_ephem.propagate(t0)

        r_sc  = sc_state.getPVCoordinates(frame).getPosition()
        r_sat = sat_state.getPVCoordinates(frame).getPosition()

        dx = r_sat.getX() - r_sc.getX()
        dy = r_sat.getY() - r_sc.getY()
        dz = r_sat.getZ() - r_sc.getZ()

        rng_km = math.sqrt(dx*dx + dy*dy + dz*dz) / 1000.0

        print(f"Sat {key:>3} ({global_id_map[key]}): "
              f"contact-start range = {rng_km:.2f} km at {t0}")
# Out:
# Dummy spacecraft orbit created:
#   Altitude : 500.0 km
#   Period   : 94.62 min
#   Inc      : 37.0 deg
#
# Numerical spacecraft propagator configured with:
#   - Earth gravity: J2 only
#   - Third body: Sun
#   - Third body: Moon
#   - Drag: Harris-Priester + IsotropicDrag
#   - Mass = 50.00 kg, Cd = 2.20, Area = 15.000 m^2
# Set nadir-pointing attitude for 85 Globalstar propagators.
#
# Propagating spacecraft once to build ephemeris...
# ✅ Spacecraft ephemeris generated
#   Start : 2026-03-14T18:59:00.000Z
#   End   : 2026-03-15T18:59:00.000Z
#
# Initial detector debug for satellite 0 (GLOBALSTAR M001):
#   LOS g           = 299985.3384694795
#   inside-FOV g    = 0.039588960815515106
#   within-range g  = -3315909.4813223146
#
# ================ CONTACT ANALYSIS ================
#
# FOV half-angle : 60.0 deg
# Max range      : 2500.0 km
# Start          : 2026-03-14T18:59:00.000Z
# End            : 2026-03-15T18:59:00.000Z
#
#
# ================ CONTACT WINDOWS ================
#
# FOV half-angle : 60.0 deg
# Max range      : 2500.0 km
#
#  Idx   Globalstar ID                    Start UTC                      End UTC  Dur (min)
# -----------------------------------------------------------------------------------------------
#    0 GLOBALSTAR M001 2026-03-14T19:07:10.37793449142034Z 2026-03-14T19:12:32.68616212898566Z       5.37
#    0 GLOBALSTAR M001 2026-03-14T19:59:02.43427755216643Z 2026-03-14T20:02:51.59234938131107Z       3.82
#    0 GLOBALSTAR M001 2026-03-15T03:46:00.2515781398478Z 2026-03-15T03:54:34.67441826028386Z       8.57
#    0 GLOBALSTAR M001 2026-03-15T12:26:37.70327812996442Z 2026-03-15T12:34:30.93791114557317Z       7.89
#    1 GLOBALSTAR M004 2026-03-15T03:06:05.68460605171074Z 2026-03-15T03:13:37.21075504076705Z       7.53
#    1 GLOBALSTAR M004 2026-03-15T03:56:10.22912272968384Z 2026-03-15T04:02:33.48055353156839Z       6.39
#    1 GLOBALSTAR M004 2026-03-15T12:30:34.38178130466276Z 2026-03-15T12:42:59.60979712730877Z      12.42
#    2 GLOBALSTAR M002 2026-03-14T22:19:42.27004208504166Z 2026-03-14T22:27:54.06671330884339Z       8.20
#    2 GLOBALSTAR M002 2026-03-15T04:36:17.84353268098093Z 2026-03-15T04:43:05.97236906450841Z       6.80
#    2 GLOBALSTAR M002 2026-03-15T11:44:58.64437292595025Z 2026-03-15T11:48:24.54276122273098Z       3.43
#    2 GLOBALSTAR M002 2026-03-15T17:58:02.67361257979506Z 2026-03-15T18:06:57.62512726389743Z       8.92
#    3 GLOBALSTAR M003 2026-03-14T23:26:20.53046286357749Z 2026-03-14T23:29:39.80188898172715Z       3.32
#    3 GLOBALSTAR M003 2026-03-15T00:18:30.49321069655269Z 2026-03-15T00:20:29.23919700766123Z       1.98
#    3 GLOBALSTAR M003 2026-03-15T07:17:11.89028385228061Z 2026-03-15T07:24:32.33838390750419Z       7.34
#    7 GLOBALSTAR M008         4        24.22        0.40
#    8 GLOBALSTAR M023         3        26.16        0.44
#    9 GLOBALSTAR M040         3        27.04        0.45
#   10 GLOBALSTAR M036         4        30.26        0.50
#   11 GLOBALSTAR M038         3       121.51        2.03
#   12 GLOBALSTAR M022         3        23.26        0.39
#   13 GLOBALSTAR M041         4        18.51        0.31
#   14 GLOBALSTAR M046         6        25.52        0.43
#   15 GLOBALSTAR M037         4        38.88        0.65
#   16 GLOBALSTAR M045         4        23.27        0.39
#   17 GLOBALSTAR M019         3        63.03        1.05
#   18 GLOBALSTAR M044         4        71.02        1.18
#   19 GLOBALSTAR M042         3       117.25        1.95
#   20 GLOBALSTAR M025         2        12.35        0.21
#   21 GLOBALSTAR M049         3        23.38        0.39
#   22 GLOBALSTAR M047         3        18.62        0.31
#   23 GLOBALSTAR M052         3        44.01        0.73
#   24 GLOBALSTAR M035         3        15.12        0.25
#   25 GLOBALSTAR M032         2        25.74        0.43
#   26 GLOBALSTAR M051         3        16.15        0.27
#   27 GLOBALSTAR M030         3        19.04        0.32
#   28 GLOBALSTAR M048         3        41.71        0.70
#   29 GLOBALSTAR M026         3        16.33        0.27
#   30 GLOBALSTAR M043         4        19.53        0.33
#   31 GLOBALSTAR M028         3        29.88        0.50
#   32 GLOBALSTAR M024         2        11.88        0.20
#   33 GLOBALSTAR M027         3        14.94        0.25
#   34 GLOBALSTAR M054         1         3.64        0.06
#   35 GLOBALSTAR M053         3        19.20        0.32
#   36 GLOBALSTAR M058         4        32.58        0.54
#   37 GLOBALSTAR M050         2        19.01        0.32
#   38 GLOBALSTAR M033         3        32.77        0.55
#   39 GLOBALSTAR M055         3        27.31        0.46
#   40 GLOBALSTAR M057         3        32.00        0.53
#   41 GLOBALSTAR M059         3        17.16        0.29
#   42 GLOBALSTAR M056         5        20.50        0.34
#   43 GLOBALSTAR M031         2        20.90        0.35
#   44 GLOBALSTAR M039         4        26.62        0.44
#   45 GLOBALSTAR M034         4       103.11        1.72
#   46 GLOBALSTAR M029         3        28.70        0.48
#   47 GLOBALSTAR M061         4        22.21        0.37
#   48 GLOBALSTAR M063         3         5.67        0.09
#   49 GLOBALSTAR M062         3       107.40        1.79
#   50 GLOBALSTAR M060         3       124.87        2.08
#   51 GLOBALSTAR M064         3        19.04        0.32
#   52 GLOBALSTAR M065         2        16.75        0.28
#   53 GLOBALSTAR M069         3        14.25        0.24
#   54 GLOBALSTAR M072         3        40.18        0.67
#   55 GLOBALSTAR M071         5        20.75        0.35
#   56 GLOBALSTAR M067         3        39.99        0.67
#   57 GLOBALSTAR M070         3       132.59        2.21
#   58 GLOBALSTAR M066         3        37.95        0.63
#   59 GLOBALSTAR M068         4        23.21        0.39
#   60 GLOBALSTAR M079         2        59.15        0.99
#   61 GLOBALSTAR M074         5       111.21        1.85
#   62 GLOBALSTAR M076         4       108.50        1.81
#   63 GLOBALSTAR M077         4        46.48        0.77
#   64 GLOBALSTAR M075         3        29.15        0.49
#   65 GLOBALSTAR M073         2        43.95        0.73
#   66 GLOBALSTAR M083         3        31.40        0.52
#   67 GLOBALSTAR M088         5        28.86        0.48
#   68 GLOBALSTAR M091         5        26.40        0.44
#   69 GLOBALSTAR M085         5        31.24        0.52
#   70 GLOBALSTAR M081         2        17.79        0.30
#   71 GLOBALSTAR M089         3        37.97        0.63
#   72 GLOBALSTAR M084         2        21.00        0.35
#   73 GLOBALSTAR M080         4        36.19        0.60
#   74 GLOBALSTAR M082         3        20.11        0.34
#   75 GLOBALSTAR M092         4        78.53        1.31
#   76 GLOBALSTAR M090         5        29.61        0.49
#   77 GLOBALSTAR M086         4        28.02        0.47
#   78 GLOBALSTAR M097         4        25.19        0.42
#   79 GLOBALSTAR M093         3        18.10        0.30
#   80 GLOBALSTAR M094         3        33.20        0.55
#   81 GLOBALSTAR M096         4        24.13        0.40
#   82 GLOBALSTAR M078         4        25.85        0.43
#   83 GLOBALSTAR M095         3        18.52        0.31
#   84 GLOBALSTAR M087         4        71.79        1.20
#
# Total contact windows found: 285
#
# ========== DEBUG RANGE AT CONTACT START ==========
#
# Sat   0 (GLOBALSTAR M001): contact-start range = 2500.00 km at 2026-03-14T19:07:10.37793449142034Z
# Sat   0 (GLOBALSTAR M001): contact-start range = 2500.00 km at 2026-03-14T19:59:02.43427755216643Z
# Sat   0 (GLOBALSTAR M001): contact-start range = 2500.00 km at 2026-03-15T03:46:00.2515781398478Z
# Sat   0 (GLOBALSTAR M001): contact-start range = 2500.00 km at 2026-03-15T12:26:37.70327812996442Z
# Sat   1 (GLOBALSTAR M004): contact-start range = 2500.00 km at 2026-03-15T03:06:05.68460605171074Z
# Sat   1 (GLOBALSTAR M004): contact-start range = 2500.00 km at 2026-03-15T03:56:10.22912272968384Z
# Sat   1 (GLOBALSTAR M004): contact-start range = 2500.00 km at 2026-03-15T12:30:34.38178130466276Z
# Sat   2 (GLOBALSTAR M002): contact-start range = 2500.00 km at 2026-03-14T22:19:42.27004208504166Z
# Sat   2 (GLOBALSTAR M002): contact-start range = 2500.00 km at 2026-03-15T04:36:17.84353268098093Z
# Sat   2 (GLOBALSTAR M002): contact-start range = 2500.00 km at 2026-03-15T11:44:58.64437292595025Z
# Sat   2 (GLOBALSTAR M002): contact-start range = 2500.00 km at 2026-03-15T17:58:02.67361257979506Z
# Sat   3 (GLOBALSTAR M003): contact-start range = 2500.00 km at 2026-03-14T23:26:20.53046286357749Z
# Sat   3 (GLOBALSTAR M003): contact-start range = 2500.00 km at 2026-03-15T00:18:30.49321069655269Z
# Sat   3 (GLOBALSTAR M003): contact-start range = 2500.00 km at 2026-03-15T07:17:11.89028385228061Z
# Sat   3 (GLOBALSTAR M003): contact-start range = 2500.00 km at 2026-03-15T15:09:34.97032944924314Z
# Sat   4 (GLOBALSTAR M014): contact-start range = 2500.00 km at 2026-03-14T22:50:32.52874684840272Z
# Sat   4 (GLOBALSTAR M014): contact-start range = 2500.00 km at 2026-03-15T05:57:01.72921997612307Z
# Sat   4 (GLOBALSTAR M014): contact-start range = 2500.00 km at 2026-03-15T12:12:35.23230325777431Z
# Sat   5 (GLOBALSTAR M006): contact-start range = 2500.00 km at 2026-03-14T19:09:52.63635826158934Z
# Sat   5 (GLOBALSTAR M006): contact-start range = 2500.00 km at 2026-03-15T01:24:32.34874286685569Z
# Sat   5 (GLOBALSTAR M006): contact-start range = 2500.00 km at 2026-03-15T07:42:04.24708424250628Z
# Sat   5 (GLOBALSTAR M006): contact-start range = 2500.00 km at 2026-03-15T14:50:16.785786800177Z
# Sat   6 (GLOBALSTAR M015): contact-start range = 2500.00 km at 2026-03-15T00:51:15.59772084872449Z
# Sat   6 (GLOBALSTAR M015): contact-start range = 2500.00 km at 2026-03-15T07:10:54.73857589705919Z
# Sat   6 (GLOBALSTAR M015): contact-start range = 2500.00 km at 2026-03-15T13:30:41.27326769515885Z
# Sat   7 (GLOBALSTAR M008): contact-start range = 2500.00 km at 2026-03-14T21:03:12.74747274825802Z
# Sat   7 (GLOBALSTAR M008): contact-start range = 2500.00 km at 2026-03-14T21:54:28.01052045824594Z
# Sat   7 (GLOBALSTAR M008): contact-start range = 2500.00 km at 2026-03-15T05:42:01.208732955406Z
# Sat   7 (GLOBALSTAR M008): contact-start range = 2500.00 km at 2026-03-15T14:23:48.57393475767499Z
# Sat   8 (GLOBALSTAR M023): contact-start range = 2500.00 km at 2026-03-15T03:06:11.25086829380501Z
# Sat   8 (GLOBALSTAR M023): contact-start range = 2500.00 km at 2026-03-15T03:56:42.47631761277043Z
# Sat   8 (GLOBALSTAR M023): contact-start range = 2500.00 km at 2026-03-15T12:30:41.91996584028099Z
# Sat   9 (GLOBALSTAR M040): contact-start range = 2500.00 km at 2026-03-15T03:06:43.29339852635503Z
# Sat   9 (GLOBALSTAR M040): contact-start range = 2500.00 km at 2026-03-15T03:57:53.55270457866295Z
# Sat   9 (GLOBALSTAR M040): contact-start range = 2500.00 km at 2026-03-15T12:31:14.78740305403478Z
# Sat  10 (GLOBALSTAR M036): contact-start range = 2500.00 km at 2026-03-14T19:04:23.31885155314392Z
# Sat  10 (GLOBALSTAR M036): contact-start range = 2500.00 km at 2026-03-15T02:08:58.30080058803823Z
# Sat  10 (GLOBALSTAR M036): contact-start range = 2500.00 km at 2026-03-15T09:13:29.05754656469551Z
# Sat  10 (GLOBALSTAR M036): contact-start range = 2500.00 km at 2026-03-15T16:17:57.84946161188257Z
# Sat  11 (GLOBALSTAR M038): contact-start range = 2500.00 km at 2026-03-14T19:44:33.31530017372751Z
# Sat  11 (GLOBALSTAR M038): contact-start range = 2500.00 km at 2026-03-15T04:02:53.3951958729156Z
# Sat  11 (GLOBALSTAR M038): contact-start range = 2500.00 km at 2026-03-15T12:06:01.93816254077295Z
# Sat  12 (GLOBALSTAR M022): contact-start range = 2500.00 km at 2026-03-15T00:38:51.85811213981329Z
# Sat  12 (GLOBALSTAR M022): contact-start range = 2500.00 km at 2026-03-15T08:33:08.69956694082952Z
# Sat  12 (GLOBALSTAR M022): contact-start range = 2500.00 km at 2026-03-15T15:35:05.27236617469033Z
# Sat  13 (GLOBALSTAR M041): contact-start range = 2500.00 km at 2026-03-15T00:18:45.805983560666Z
# Sat  13 (GLOBALSTAR M041): contact-start range = 2500.00 km at 2026-03-15T07:22:20.55878645443153Z
# Sat  13 (GLOBALSTAR M041): contact-start range = 2500.00 km at 2026-03-15T14:28:11.35428223571797Z
# Sat  13 (GLOBALSTAR M041): contact-start range = 2500.00 km at 2026-03-15T15:19:00.42934277850035Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2126.07 km at 2026-03-14T18:59:00.000Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2500.00 km at 2026-03-14T19:51:14.55563518265143Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2500.00 km at 2026-03-15T02:49:53.54965840801486Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2500.00 km at 2026-03-15T10:43:23.6390151714723Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2500.00 km at 2026-03-15T17:45:51.96416156900823Z
# Sat  14 (GLOBALSTAR M046): contact-start range = 2500.00 km at 2026-03-15T18:38:56.27552689647629Z
# Sat  15 (GLOBALSTAR M037): contact-start range = 2500.00 km at 2026-03-14T21:39:09.20257719977148Z
# Sat  15 (GLOBALSTAR M037): contact-start range = 2500.00 km at 2026-03-15T07:04:29.73379938303881Z
# Sat  15 (GLOBALSTAR M037): contact-start range = 2500.00 km at 2026-03-15T15:46:57.94025834945873Z
# Sat  15 (GLOBALSTAR M037): contact-start range = 2500.00 km at 2026-03-15T16:33:32.40562589907504Z
# Sat  16 (GLOBALSTAR M045): contact-start range = 2500.00 km at 2026-03-15T02:11:01.08776391053888Z
# Sat  16 (GLOBALSTAR M045): contact-start range = 2500.00 km at 2026-03-15T03:00:23.31022178446391Z
# Sat  16 (GLOBALSTAR M045): contact-start range = 2500.00 km at 2026-03-15T10:50:03.29053657765098Z
# Sat  16 (GLOBALSTAR M045): contact-start range = 2500.00 km at 2026-03-15T18:40:31.90353995921548Z
# Sat  17 (GLOBALSTAR M019): contact-start range = 2500.00 km at 2026-03-14T23:04:47.31425321909155Z
# Sat  17 (GLOBALSTAR M019): contact-start range = 2500.00 km at 2026-03-15T06:52:04.84877244356081Z
# Sat  17 (GLOBALSTAR M019): contact-start range = 2500.00 km at 2026-03-15T14:41:33.23644546431861Z
# Sat  18 (GLOBALSTAR M044): contact-start range = 2500.00 km at 2026-03-14T22:56:22.08159188707141Z
# Sat  18 (GLOBALSTAR M044): contact-start range = 2500.00 km at 2026-03-15T06:05:24.46902957197586Z
# Sat  18 (GLOBALSTAR M044): contact-start range = 2500.00 km at 2026-03-15T13:17:10.29117620922003Z
# Sat  18 (GLOBALSTAR M044): contact-start range = 2500.00 km at 2026-03-15T13:43:01.33575730211096Z
# Sat  19 (GLOBALSTAR M042): contact-start range = 2500.00 km at 2026-03-14T20:20:49.34957032712048Z
# Sat  19 (GLOBALSTAR M042): contact-start range = 2500.00 km at 2026-03-15T04:15:44.58856286589297Z
# Sat  19 (GLOBALSTAR M042): contact-start range = 2500.00 km at 2026-03-15T12:10:53.97072063602163Z
# Sat  20 (GLOBALSTAR M025): contact-start range = 2500.00 km at 2026-03-15T03:44:34.8298856663885Z
# Sat  20 (GLOBALSTAR M025): contact-start range = 2500.00 km at 2026-03-15T15:32:03.83864828810829Z
# Sat  21 (GLOBALSTAR M049): contact-start range = 2500.00 km at 2026-03-14T23:10:27.5735920784842Z
# Sat  21 (GLOBALSTAR M049): contact-start range = 2500.00 km at 2026-03-15T04:40:10.41873420303441Z
# Sat  21 (GLOBALSTAR M049): contact-start range = 2500.00 km at 2026-03-15T16:26:56.13406987855716Z
# Sat  22 (GLOBALSTAR M047): contact-start range = 2500.00 km at 2026-03-14T22:20:27.4982453028598Z
# Sat  22 (GLOBALSTAR M047): contact-start range = 2500.00 km at 2026-03-15T10:05:12.9000890321166Z
# Sat  22 (GLOBALSTAR M047): contact-start range = 2500.00 km at 2026-03-15T16:22:39.35881689325733Z
# Sat  23 (GLOBALSTAR M052): contact-start range = 2500.00 km at 2026-03-14T21:26:42.74518869346188Z
# Sat  23 (GLOBALSTAR M052): contact-start range = 2500.00 km at 2026-03-15T03:01:21.33695599695206Z
# Sat  23 (GLOBALSTAR M052): contact-start range = 2500.00 km at 2026-03-15T14:46:33.66386479180323Z
# Sat  24 (GLOBALSTAR M035): contact-start range = 2500.00 km at 2026-03-14T21:10:57.89892055936043Z
# Sat  24 (GLOBALSTAR M035): contact-start range = 2500.00 km at 2026-03-15T09:02:01.03182393030036Z
# Sat  24 (GLOBALSTAR M035): contact-start range = 2500.00 km at 2026-03-15T14:29:38.36654028851768Z
# Sat  25 (GLOBALSTAR M032): contact-start range = 2500.00 km at 2026-03-15T05:31:29.9055200657474Z
# Sat  25 (GLOBALSTAR M032): contact-start range = 2500.00 km at 2026-03-15T17:18:54.64583771131172Z
# Sat  26 (GLOBALSTAR M051): contact-start range = 2500.00 km at 2026-03-15T00:08:39.68447543633045Z
# Sat  26 (GLOBALSTAR M051): contact-start range = 2500.00 km at 2026-03-15T06:25:34.65802989532978Z
# Sat  26 (GLOBALSTAR M051): contact-start range = 2500.00 km at 2026-03-15T12:42:35.36250417152775Z
# Sat  27 (GLOBALSTAR M030): contact-start range = 2500.00 km at 2026-03-14T19:06:37.48950478445988Z
# Sat  27 (GLOBALSTAR M030): contact-start range = 2500.00 km at 2026-03-15T01:23:20.95382875175813Z
# Sat  27 (GLOBALSTAR M030): contact-start range = 2500.00 km at 2026-03-15T14:48:36.84456356939884Z
# Sat  28 (GLOBALSTAR M048): contact-start range = 2500.00 km at 2026-03-15T04:38:15.79984592269161Z
# Sat  28 (GLOBALSTAR M048): contact-start range = 2500.00 km at 2026-03-15T10:52:58.48849135861607Z
# Sat  28 (GLOBALSTAR M048): contact-start range = 2500.00 km at 2026-03-15T17:11:22.83866194035382Z
# Sat  29 (GLOBALSTAR M026): contact-start range = 2500.00 km at 2026-03-14T23:09:10.43658327834902Z
# Sat  29 (GLOBALSTAR M026): contact-start range = 2500.00 km at 2026-03-15T10:55:35.90432107318784Z
# Sat  29 (GLOBALSTAR M026): contact-start range = 2500.00 km at 2026-03-15T16:25:06.23131922498893Z
# Sat  30 (GLOBALSTAR M043): contact-start range = 2500.00 km at 2026-03-14T19:36:53.08564807167294Z
# Sat  30 (GLOBALSTAR M043): contact-start range = 2500.00 km at 2026-03-15T01:57:43.72457869799057Z
# Sat  30 (GLOBALSTAR M043): contact-start range = 2500.00 km at 2026-03-15T07:24:53.16160619320721Z
# Sat  30 (GLOBALSTAR M043): contact-start range = 2500.00 km at 2026-03-15T13:42:25.27084650179663Z
# Sat  31 (GLOBALSTAR M028): contact-start range = 2500.00 km at 2026-03-14T22:33:10.42919722958527Z
# Sat  31 (GLOBALSTAR M028): contact-start range = 2500.00 km at 2026-03-15T07:11:43.05825094350022Z
# Sat  31 (GLOBALSTAR M028): contact-start range = 2500.00 km at 2026-03-15T15:49:54.81363338537705Z
# Sat  32 (GLOBALSTAR M024): contact-start range = 2500.00 km at 2026-03-15T04:56:10.59896302820758Z
# Sat  32 (GLOBALSTAR M024): contact-start range = 2500.00 km at 2026-03-15T10:25:17.55181970522323Z
# Sat  33 (GLOBALSTAR M027): contact-start range = 2500.00 km at 2026-03-14T23:42:12.76591567718208Z
# Sat  33 (GLOBALSTAR M027): contact-start range = 2500.00 km at 2026-03-15T05:11:58.02195067415628Z
# Sat  33 (GLOBALSTAR M027): contact-start range = 2500.00 km at 2026-03-15T17:02:19.30043905975961Z
# Sat  34 (GLOBALSTAR M054): contact-start range = 2500.00 km at 2026-03-14T23:59:31.31084843543662Z
# Sat  35 (GLOBALSTAR M053): contact-start range = 2500.00 km at 2026-03-15T00:36:53.59727969409259Z
# Sat  35 (GLOBALSTAR M053): contact-start range = 2500.00 km at 2026-03-15T06:55:54.79524437172152Z
# Sat  35 (GLOBALSTAR M053): contact-start range = 2500.00 km at 2026-03-15T18:41:52.45421066904086Z
# Sat  36 (GLOBALSTAR M058): contact-start range = 2500.00 km at 2026-03-14T19:24:30.13768443250765Z
# Sat  36 (GLOBALSTAR M058): contact-start range = 2500.00 km at 2026-03-15T02:28:09.32715889061865Z
# Sat  36 (GLOBALSTAR M058): contact-start range = 2500.00 km at 2026-03-15T09:32:41.60884011782189Z
# Sat  36 (GLOBALSTAR M058): contact-start range = 2500.00 km at 2026-03-15T16:38:28.58802503115241Z
# Sat  37 (GLOBALSTAR M050): contact-start range = 2500.00 km at 2026-03-15T01:38:58.9541400157067Z
# Sat  37 (GLOBALSTAR M050): contact-start range = 2500.00 km at 2026-03-15T09:30:13.22425797766029Z
# Sat  38 (GLOBALSTAR M033): contact-start range = 2500.00 km at 2026-03-14T23:09:00.09310934521936Z
# Sat  38 (GLOBALSTAR M033): contact-start range = 2500.00 km at 2026-03-15T07:00:45.75098434111766Z
# Sat  38 (GLOBALSTAR M033): contact-start range = 2500.00 km at 2026-03-15T14:52:24.05675468689708Z
# Sat  39 (GLOBALSTAR M055): contact-start range = 2500.00 km at 2026-03-14T22:21:17.8681547121368Z
# Sat  39 (GLOBALSTAR M055): contact-start range = 2500.00 km at 2026-03-15T06:14:57.25563045436435Z
# Sat  39 (GLOBALSTAR M055): contact-start range = 2500.00 km at 2026-03-15T14:53:19.22023539621005Z
# Sat  40 (GLOBALSTAR M057): contact-start range = 2500.00 km at 2026-03-15T00:43:43.03383939726018Z
# Sat  40 (GLOBALSTAR M057): contact-start range = 2500.00 km at 2026-03-15T08:34:25.88555643271247Z
# Sat  40 (GLOBALSTAR M057): contact-start range = 2500.00 km at 2026-03-15T16:25:38.22749774206794Z
# Sat  41 (GLOBALSTAR M059): contact-start range = 2500.00 km at 2026-03-14T22:53:07.65956251908374Z
# Sat  41 (GLOBALSTAR M059): contact-start range = 2500.00 km at 2026-03-15T05:54:51.99667184313132Z
# Sat  41 (GLOBALSTAR M059): contact-start range = 2500.00 km at 2026-03-15T12:58:40.0300363055165Z
# Sat  42 (GLOBALSTAR M056): contact-start range = 2500.00 km at 2026-03-14T22:01:21.84399531112074Z
# Sat  42 (GLOBALSTAR M056): contact-start range = 2500.00 km at 2026-03-14T22:54:06.86692571557629Z
# Sat  42 (GLOBALSTAR M056): contact-start range = 2500.00 km at 2026-03-15T05:53:51.954358024688Z
# Sat  42 (GLOBALSTAR M056): contact-start range = 2500.00 km at 2026-03-15T12:58:10.05447236679342Z
# Sat  42 (GLOBALSTAR M056): contact-start range = 2500.00 km at 2026-03-15T13:49:22.62753830992256Z
# Sat  43 (GLOBALSTAR M031): contact-start range = 2500.00 km at 2026-03-15T00:45:10.58636182981124Z
# Sat  43 (GLOBALSTAR M031): contact-start range = 2500.00 km at 2026-03-15T15:42:47.94723129858367Z
# Sat  44 (GLOBALSTAR M039): contact-start range = 2500.00 km at 2026-03-14T21:09:42.3547322331497Z
# Sat  44 (GLOBALSTAR M039): contact-start range = 2500.00 km at 2026-03-15T05:47:34.60646517168247Z
# Sat  44 (GLOBALSTAR M039): contact-start range = 2500.00 km at 2026-03-15T06:38:12.70435847238359Z
# Sat  44 (GLOBALSTAR M039): contact-start range = 2500.00 km at 2026-03-15T15:13:54.79522089849854Z
# Sat  45 (GLOBALSTAR M034): contact-start range = 2500.00 km at 2026-03-14T19:03:16.35930252201645Z
# Sat  45 (GLOBALSTAR M034): contact-start range = 2500.00 km at 2026-03-15T02:01:30.15433330505575Z
# Sat  45 (GLOBALSTAR M034): contact-start range = 2500.00 km at 2026-03-15T09:01:44.12851863673878Z
# Sat  45 (GLOBALSTAR M034): contact-start range = 2500.00 km at 2026-03-15T16:02:42.92153126037061Z
# Sat  46 (GLOBALSTAR M029): contact-start range = 2500.00 km at 2026-03-15T00:48:13.93652609499041Z
# Sat  46 (GLOBALSTAR M029): contact-start range = 2500.00 km at 2026-03-15T07:55:45.19885845729868Z
# Sat  46 (GLOBALSTAR M029): contact-start range = 2500.00 km at 2026-03-15T15:46:00.96835706057155Z
# Sat  47 (GLOBALSTAR M061): contact-start range = 2500.00 km at 2026-03-14T21:23:39.19455546895733Z
# Sat  47 (GLOBALSTAR M061): contact-start range = 2500.00 km at 2026-03-15T03:36:59.09601306077508Z
# Sat  47 (GLOBALSTAR M061): contact-start range = 2500.00 km at 2026-03-15T10:41:42.25644997028251Z
# Sat  47 (GLOBALSTAR M061): contact-start range = 2500.00 km at 2026-03-15T17:47:25.89601199441607Z
# Sat  48 (GLOBALSTAR M063): contact-start range = 2500.00 km at 2026-03-15T01:45:22.90574012627598Z
# Sat  48 (GLOBALSTAR M063): contact-start range = 2500.00 km at 2026-03-15T08:50:14.44981452972963Z
# Sat  48 (GLOBALSTAR M063): contact-start range = 2500.00 km at 2026-03-15T15:54:13.79932560648238Z
# Sat  49 (GLOBALSTAR M062): contact-start range = 2500.00 km at 2026-03-14T22:40:23.57670393283294Z
# Sat  49 (GLOBALSTAR M062): contact-start range = 2500.00 km at 2026-03-15T07:14:53.9156006445446Z
# Sat  49 (GLOBALSTAR M062): contact-start range = 2500.00 km at 2026-03-15T15:46:33.28433368666739Z
# Sat  50 (GLOBALSTAR M060): contact-start range = 2500.00 km at 2026-03-14T20:44:19.80924082580207Z
# Sat  50 (GLOBALSTAR M060): contact-start range = 2500.00 km at 2026-03-15T04:26:24.54629486564935Z
# Sat  50 (GLOBALSTAR M060): contact-start range = 2500.00 km at 2026-03-15T12:13:16.31455382126782Z
# Sat  51 (GLOBALSTAR M064): contact-start range = 2500.00 km at 2026-03-15T00:30:45.35172288624062Z
# Sat  51 (GLOBALSTAR M064): contact-start range = 2500.00 km at 2026-03-15T07:34:42.26098347454791Z
# Sat  51 (GLOBALSTAR M064): contact-start range = 2500.00 km at 2026-03-15T14:38:47.06985924273167Z
# Sat  52 (GLOBALSTAR M065): contact-start range = 2500.00 km at 2026-03-15T00:58:29.74819074579874Z
# Sat  52 (GLOBALSTAR M065): contact-start range = 2500.00 km at 2026-03-15T09:35:18.08765457341045Z
# Sat  53 (GLOBALSTAR M069): contact-start range = 2500.00 km at 2026-03-15T02:38:25.7827017131908Z
# Sat  53 (GLOBALSTAR M069): contact-start range = 2500.00 km at 2026-03-15T03:29:39.03008869233171Z
# Sat  53 (GLOBALSTAR M069): contact-start range = 2500.00 km at 2026-03-15T11:20:06.25351253802966Z
# Sat  54 (GLOBALSTAR M072): contact-start range = 2500.00 km at 2026-03-15T04:45:15.36808599420952Z
# Sat  54 (GLOBALSTAR M072): contact-start range = 2500.00 km at 2026-03-15T11:48:25.26047429062109Z
# Sat  54 (GLOBALSTAR M072): contact-start range = 2500.00 km at 2026-03-15T18:53:15.58722516455031Z
# Sat  55 (GLOBALSTAR M071): contact-start range = 2500.00 km at 2026-03-14T22:48:48.14510798298996Z
# Sat  55 (GLOBALSTAR M071): contact-start range = 2500.00 km at 2026-03-14T23:41:33.81545398231206Z
# Sat  55 (GLOBALSTAR M071): contact-start range = 2500.00 km at 2026-03-15T06:40:35.12450539728355Z
# Sat  55 (GLOBALSTAR M071): contact-start range = 2500.00 km at 2026-03-15T07:34:27.65715236908781Z
# Sat  55 (GLOBALSTAR M071): contact-start range = 2500.00 km at 2026-03-15T14:32:19.22777704758732Z
# Sat  56 (GLOBALSTAR M067): contact-start range = 2500.00 km at 2026-03-14T20:03:08.87978551054105Z
# Sat  56 (GLOBALSTAR M067): contact-start range = 2500.00 km at 2026-03-15T04:40:51.40156926469756Z
# Sat  56 (GLOBALSTAR M067): contact-start range = 2500.00 km at 2026-03-15T13:20:42.33969960327428Z
# Sat  57 (GLOBALSTAR M070): contact-start range = 2500.00 km at 2026-03-14T22:09:12.35049849908812Z
# Sat  57 (GLOBALSTAR M070): contact-start range = 2500.00 km at 2026-03-15T07:23:05.41839809388165Z
# Sat  57 (GLOBALSTAR M070): contact-start range = 2500.00 km at 2026-03-15T16:35:22.98942836791767Z
# Sat  58 (GLOBALSTAR M066): contact-start range = 2500.00 km at 2026-03-14T22:24:11.8739024164395Z
# Sat  58 (GLOBALSTAR M066): contact-start range = 2500.00 km at 2026-03-15T06:19:32.83352482309564Z
# Sat  58 (GLOBALSTAR M066): contact-start range = 2500.00 km at 2026-03-15T14:55:22.05362999117254Z
# Sat  59 (GLOBALSTAR M068): contact-start range = 2500.00 km at 2026-03-14T19:43:46.69140730966721Z
# Sat  59 (GLOBALSTAR M068): contact-start range = 2500.00 km at 2026-03-15T04:19:59.36473234477351Z
# Sat  59 (GLOBALSTAR M068): contact-start range = 2500.00 km at 2026-03-15T05:13:28.10212162123676Z
# Sat  59 (GLOBALSTAR M068): contact-start range = 2500.00 km at 2026-03-15T13:47:14.97665267586413Z
# Sat  60 (GLOBALSTAR M079): contact-start range = 2500.00 km at 2026-03-15T01:17:28.19008094139886Z
# Sat  60 (GLOBALSTAR M079): contact-start range = 2500.00 km at 2026-03-15T10:37:31.7160797287256Z
# Sat  61 (GLOBALSTAR M074): contact-start range = 2500.00 km at 2026-03-14T22:10:41.91109270517976Z
# Sat  61 (GLOBALSTAR M074): contact-start range = 2500.00 km at 2026-03-14T22:52:34.46925055123209Z
# Sat  61 (GLOBALSTAR M074): contact-start range = 2500.00 km at 2026-03-15T07:29:22.54909178754712Z
# Sat  61 (GLOBALSTAR M074): contact-start range = 2500.00 km at 2026-03-15T16:22:19.55434024574732Z
# Sat  61 (GLOBALSTAR M074): contact-start range = 2500.00 km at 2026-03-15T16:54:04.94851480501091Z
# Sat  62 (GLOBALSTAR M076): contact-start range = 2500.00 km at 2026-03-14T19:06:42.25743764315683Z
# Sat  62 (GLOBALSTAR M076): contact-start range = 2500.00 km at 2026-03-14T19:35:24.5419736291019Z
# Sat  62 (GLOBALSTAR M076): contact-start range = 2500.00 km at 2026-03-15T04:22:58.39244835820615Z
# Sat  62 (GLOBALSTAR M076): contact-start range = 2500.00 km at 2026-03-15T13:44:34.42164896555278Z
# Sat  63 (GLOBALSTAR M077): contact-start range = 2500.00 km at 2026-03-14T20:46:08.81820004382408Z
# Sat  63 (GLOBALSTAR M077): contact-start range = 2500.00 km at 2026-03-15T03:05:48.37026354316789Z
# Sat  63 (GLOBALSTAR M077): contact-start range = 2500.00 km at 2026-03-15T10:07:41.92099829973628Z
# Sat  63 (GLOBALSTAR M077): contact-start range = 2500.00 km at 2026-03-15T16:29:59.52911739990378Z
# Sat  64 (GLOBALSTAR M075): contact-start range = 2500.00 km at 2026-03-15T03:55:05.89468938568958Z
# Sat  64 (GLOBALSTAR M075): contact-start range = 2500.00 km at 2026-03-15T12:37:25.70327203256664Z
# Sat  64 (GLOBALSTAR M075): contact-start range = 2500.00 km at 2026-03-15T13:24:29.97053315387606Z
# Sat  65 (GLOBALSTAR M073): contact-start range = 2500.00 km at 2026-03-15T02:21:17.97427346417056Z
# Sat  65 (GLOBALSTAR M073): contact-start range = 2500.00 km at 2026-03-15T11:04:39.84785099498465Z
# Sat  66 (GLOBALSTAR M083): contact-start range = 2500.00 km at 2026-03-14T23:56:07.08817181968715Z
# Sat  66 (GLOBALSTAR M083): contact-start range = 2500.00 km at 2026-03-15T08:34:04.69237612026613Z
# Sat  66 (GLOBALSTAR M083): contact-start range = 2500.00 km at 2026-03-15T17:59:58.53978943761155Z
# Sat  67 (GLOBALSTAR M088): contact-start range = 2500.00 km at 2026-03-14T23:38:31.41807631093239Z
# Sat  67 (GLOBALSTAR M088): contact-start range = 2500.00 km at 2026-03-15T00:30:11.75994279943398Z
# Sat  67 (GLOBALSTAR M088): contact-start range = 2500.00 km at 2026-03-15T09:05:27.86301351315527Z
# Sat  67 (GLOBALSTAR M088): contact-start range = 2500.00 km at 2026-03-15T17:43:51.82543654269175Z
# Sat  67 (GLOBALSTAR M088): contact-start range = 2500.00 km at 2026-03-15T18:33:24.55432218633579Z
# Sat  68 (GLOBALSTAR M091): contact-start range = 2500.00 km at 2026-03-14T21:10:10.08057122626672Z
# Sat  68 (GLOBALSTAR M091): contact-start range = 2500.00 km at 2026-03-15T05:49:02.29586783687735Z
# Sat  68 (GLOBALSTAR M091): contact-start range = 2500.00 km at 2026-03-15T06:38:14.44332917330008Z
# Sat  68 (GLOBALSTAR M091): contact-start range = 2500.00 km at 2026-03-15T15:14:36.59902693204653Z
# Sat  68 (GLOBALSTAR M091): contact-start range = 2500.00 km at 2026-03-15T16:08:28.51035429567797Z
# Sat  69 (GLOBALSTAR M085): contact-start range = 2500.00 km at 2026-03-14T21:00:05.55185518813324Z
# Sat  69 (GLOBALSTAR M085): contact-start range = 2500.00 km at 2026-03-14T21:53:28.6154017170497Z
# Sat  69 (GLOBALSTAR M085): contact-start range = 2500.00 km at 2026-03-15T06:26:45.35771851960933Z
# Sat  69 (GLOBALSTAR M085): contact-start range = 2500.00 km at 2026-03-15T15:06:01.93561224035296Z
# Sat  69 (GLOBALSTAR M085): contact-start range = 2500.00 km at 2026-03-15T15:55:23.56160576044164Z
# Sat  70 (GLOBALSTAR M081): contact-start range = 2500.00 km at 2026-03-15T03:18:02.82281576231916Z
# Sat  70 (GLOBALSTAR M081): contact-start range = 2500.00 km at 2026-03-15T12:45:37.51285300935822Z
# Sat  71 (GLOBALSTAR M089): contact-start range = 2500.00 km at 2026-03-14T21:37:38.15758525481687Z
# Sat  71 (GLOBALSTAR M089): contact-start range = 2500.00 km at 2026-03-15T07:04:17.43907936696645Z
# Sat  71 (GLOBALSTAR M089): contact-start range = 2500.00 km at 2026-03-15T15:43:52.04418257652552Z
# Sat  72 (GLOBALSTAR M084): contact-start range = 2500.00 km at 2026-03-15T03:05:39.72249964422164Z
# Sat  72 (GLOBALSTAR M084): contact-start range = 2500.00 km at 2026-03-15T11:43:14.77036075326684Z
# Sat  73 (GLOBALSTAR M080): contact-start range = 2500.00 km at 2026-03-14T20:47:16.1863121681878Z
# Sat  73 (GLOBALSTAR M080): contact-start range = 2500.00 km at 2026-03-15T06:13:20.38071745749655Z
# Sat  73 (GLOBALSTAR M080): contact-start range = 2500.00 km at 2026-03-15T14:53:45.08966227827209Z
# Sat  73 (GLOBALSTAR M080): contact-start range = 2500.00 km at 2026-03-15T15:42:39.45864849032823Z
# Sat  74 (GLOBALSTAR M082): contact-start range = 2500.00 km at 2026-03-15T02:57:55.59902572722548Z
# Sat  74 (GLOBALSTAR M082): contact-start range = 2500.00 km at 2026-03-15T03:49:43.25679663098754Z
# Sat  74 (GLOBALSTAR M082): contact-start range = 2500.00 km at 2026-03-15T12:24:22.83569455255993Z
# Sat  75 (GLOBALSTAR M092): contact-start range = 2500.00 km at 2026-03-14T23:12:36.90893176064036Z
# Sat  75 (GLOBALSTAR M092): contact-start range = 2500.00 km at 2026-03-15T07:59:30.89937634280691Z
# Sat  75 (GLOBALSTAR M092): contact-start range = 2500.00 km at 2026-03-15T08:42:53.96684400494902Z
# Sat  75 (GLOBALSTAR M092): contact-start range = 2500.00 km at 2026-03-15T17:18:27.67081275714331Z
# Sat  76 (GLOBALSTAR M090): contact-start range = 2500.00 km at 2026-03-14T23:48:05.73275295451451Z
# Sat  76 (GLOBALSTAR M090): contact-start range = 2500.00 km at 2026-03-15T00:41:36.5377598095485Z
# Sat  76 (GLOBALSTAR M090): contact-start range = 2500.00 km at 2026-03-15T09:15:06.21568212669188Z
# Sat  76 (GLOBALSTAR M090): contact-start range = 2500.00 km at 2026-03-15T17:53:19.15890330125765Z
# Sat  76 (GLOBALSTAR M090): contact-start range = 2500.00 km at 2026-03-15T18:43:38.67832783597824Z
# Sat  77 (GLOBALSTAR M086): contact-start range = 2500.00 km at 2026-03-14T21:27:29.36100740306806Z
# Sat  77 (GLOBALSTAR M086): contact-start range = 2500.00 km at 2026-03-15T06:05:55.52646572645689Z
# Sat  77 (GLOBALSTAR M086): contact-start range = 2500.00 km at 2026-03-15T06:56:01.78649993882707Z
# Sat  77 (GLOBALSTAR M086): contact-start range = 2500.00 km at 2026-03-15T15:31:44.29092767320137Z
# Sat  78 (GLOBALSTAR M097): contact-start range = 2500.00 km at 2026-03-15T00:19:15.30113209849166Z
# Sat  78 (GLOBALSTAR M097): contact-start range = 2500.00 km at 2026-03-15T08:57:50.87257385318134Z
# Sat  78 (GLOBALSTAR M097): contact-start range = 2500.00 km at 2026-03-15T09:47:21.64105223335247Z
# Sat  78 (GLOBALSTAR M097): contact-start range = 2500.00 km at 2026-03-15T18:23:35.40807921448165Z
# Sat  79 (GLOBALSTAR M093): contact-start range = 2500.00 km at 2026-03-15T02:39:01.23804847122843Z
# Sat  79 (GLOBALSTAR M093): contact-start range = 2500.00 km at 2026-03-15T03:28:49.27336063095467Z
# Sat  79 (GLOBALSTAR M093): contact-start range = 2500.00 km at 2026-03-15T12:04:57.70330043163477Z
# Sat  80 (GLOBALSTAR M094): contact-start range = 2500.00 km at 2026-03-15T00:46:24.88526757559314Z
# Sat  80 (GLOBALSTAR M094): contact-start range = 2500.00 km at 2026-03-15T10:14:19.09271542008988Z
# Sat  80 (GLOBALSTAR M094): contact-start range = 2500.00 km at 2026-03-15T18:51:54.36997961308357Z
# Sat  81 (GLOBALSTAR M096): contact-start range = 2500.00 km at 2026-03-15T00:10:05.72324947524235Z
# Sat  81 (GLOBALSTAR M096): contact-start range = 2500.00 km at 2026-03-15T01:02:16.32869971932763Z
# Sat  81 (GLOBALSTAR M096): contact-start range = 2500.00 km at 2026-03-15T09:36:37.04318640211046Z
# Sat  81 (GLOBALSTAR M096): contact-start range = 2500.00 km at 2026-03-15T18:16:02.25979008043226Z
# Sat  82 (GLOBALSTAR M078): contact-start range = 2500.00 km at 2026-03-14T21:19:50.4947633796674Z
# Sat  82 (GLOBALSTAR M078): contact-start range = 2500.00 km at 2026-03-15T05:56:58.12186920725738Z
# Sat  82 (GLOBALSTAR M078): contact-start range = 2500.00 km at 2026-03-15T06:48:40.07371452688319Z
# Sat  82 (GLOBALSTAR M078): contact-start range = 2500.00 km at 2026-03-15T15:23:50.36149852516891Z
# Sat  83 (GLOBALSTAR M095): contact-start range = 2500.00 km at 2026-03-15T02:47:44.43097233664931Z
# Sat  83 (GLOBALSTAR M095): contact-start range = 2500.00 km at 2026-03-15T03:39:30.5096813932616Z
# Sat  83 (GLOBALSTAR M095): contact-start range = 2500.00 km at 2026-03-15T12:14:40.49528674378483Z
# Sat  84 (GLOBALSTAR M087): contact-start range = 2500.00 km at 2026-03-14T20:04:05.01652658531238Z
# Sat  84 (GLOBALSTAR M087): contact-start range = 2500.00 km at 2026-03-15T04:53:13.93576865478756Z
# Sat  84 (GLOBALSTAR M087): contact-start range = 2500.00 km at 2026-03-15T05:31:56.80463003561943Z
# Sat  84 (GLOBALSTAR M087): contact-start range = 2500.00 km at 2026-03-15T14:10:23.94792534191551Z

# %%
test_key = 37
sat_prop_test = iridium_props[test_key]

los_test = InterSatDirectViewDetector(earth, sat_prop_test)

raw_fov_test = FieldOfViewDetector(
    sat_prop_test,
    0.0,
    VisibilityTrigger.VISIBLE_ONLY_WHEN_FULLY_IN_FOV,
    antenna_fov
)
fov_inside_test = BooleanDetector.notCombine(raw_fov_test)

raw_range_test = RelativeDistanceDetector(sat_prop_test, float(max_range_m))
range_within_test = BooleanDetector.notCombine(raw_range_test)

combined_test = BooleanDetector.andCombine([
    los_test,
    fov_inside_test,
    range_within_test
])

print(f"Initial detector debug for satellite {test_key} ({iridium_id_map[test_key]}):")
print("  LOS g           =", los_test.g(sc_initial_state))
print("  inside-FOV g    =", fov_inside_test.g(sc_initial_state))
print("  within-range g  =", range_within_test.g(sc_initial_state))
print("  combined g      =", combined_test.g(sc_initial_state))
# Out:
# Initial detector debug for satellite 37 (IRIDIUM 144):
#   LOS g           = -585136.31040173
#   inside-FOV g    = -2.0490200474795914
#   within-range g  = -4914754.010172269
#   combined g      = -4914754.010172269
